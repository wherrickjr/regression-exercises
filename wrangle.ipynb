# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import env
import wrangle
import os
from sklearn.model_selection import train_test_split

# %%
password = wrangle.get_connection('zillow')

# %%
pd.read_sql('select * from properties_2017 limit 10', password)
# Out:
#    id  parcelid airconditioningtypeid architecturalstyletypeid basementsqft  \
# 0   0  10754147                  None                     None         None
# 1   1  10759547                  None                     None         None
# 2   2  10843547                  None                     None         None
# 3   3  10859147                  None                     None         None
# 4   4  10879947                  None                     None         None
# 5   5  10898347                  None                     None         None
# 6   6  10933547                  None                     None         None
# 7   7  10940747                  None                     None         None
# 8   8  10954547                  None                     None         None
# 9   9  10976347                  None                     None         None
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
# 5          0.0         0.0                  4.0                    4.0
# 6          0.0         0.0                  NaN                    NaN
# 7          0.0         0.0                  NaN                    NaN
# 8          0.0         0.0                  NaN                    NaN
# 9          0.0         0.0                  3.0                    4.0
#
#   calculatedbathnbr  ... numberofstories fireplaceflag  \
# 0              None  ...             NaN          None
# 1              None  ...             NaN          None
# 2              None  ...             1.0          None
# 3              None  ...             1.0          None
# 4              None  ...             1.0          None
# 5              None  ...             1.0          None
# 6              None  ...             NaN          None
# 7              None  ...             1.0          None
# 8              None  ...             NaN          None
# 9              None  ...             1.0          None
#
#    structuretaxvaluedollarcnt taxvaluedollarcnt assessmentyear  \
# 0                         NaN               9.0         2016.0
# 1                         NaN           27516.0         2015.0
# 2                    660680.0         1434941.0         2016.0
# 3                    580059.0         1174475.0         2016.0
# 4                    196751.0          440101.0         2016.0
# 5                    179072.0          287634.0         2016.0
# 6                    404013.0          563029.0         2016.0
# 7                    103553.0          698984.0         2016.0
# 8                         NaN               9.0         2016.0
# 9                    221771.0          265184.0         2016.0
#
#    landtaxvaluedollarcnt taxamount taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0       NaN               None                None
# 1                27516.0       NaN               None                None
# 2               774261.0  20800.37               None                None
# 3               594416.0  14557.57               None                None
# 4               243350.0   5725.17               None                None
# 5               108562.0   3661.28               None                None
# 6               159016.0   6773.34               None                None
# 7               595431.0   7857.84               None                None
# 8                    9.0       NaN               None                None
# 9                43413.0   4054.76               None                None
#
#   censustractandblock
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# 5                None
# 6                None
# 7                None
# 8                None
# 9                None
#
# [10 rows x 59 columns]

# %%
df = wrangle.get_zillow_data()

# %%
df
# Out:
#          Unnamed: 0  bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 0                 0         0.0          0.0                           NaN
# 1                 1         0.0          0.0                           NaN
# 2                 2         0.0          0.0                           NaN
# 3                 3         0.0          0.0                           NaN
# 4                 4         4.0          2.0                        3633.0
# ...             ...         ...          ...                           ...
# 2152858     2152858         4.0          3.0                        2262.0
# 2152859     2152859         4.0          4.5                        3127.0
# 2152860     2152860         0.0          0.0                           NaN
# 2152861     2152861         3.0          2.5                        1974.0
# 2152862     2152862         4.0          4.0                        2110.0
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 0                  27516.0        NaN        NaN  6037.0
# 1                     10.0        NaN        NaN  6037.0
# 2                     10.0        NaN        NaN  6037.0
# 3                   2108.0        NaN     174.21  6037.0
# 4                 296425.0     2005.0    6941.39  6037.0
# ...                    ...        ...        ...     ...
# 2152858           960756.0     2015.0   13494.52  6059.0
# 2152859           536061.0     2014.0    6244.16  6059.0
# 2152860           208057.0        NaN    5783.88  6059.0
# 2152861           424353.0     2015.0    5302.70  6059.0
# 2152862           554009.0     2014.0    6761.20  6037.0
#
# [2152863 rows x 8 columns]

# %%
train, validate, test = wrangle.wrangle_zillow()

# %%
train
# Out:
#          bedrooms  bathrooms    area  tax_value  year_built  taxamount    fips
# 553191        4.0        2.0  1556.0   373090.0      1923.0    4579.25  6037.0
# 1209132       3.0        2.0  1513.0    74070.0      1937.0     986.55  6037.0
# 174634        4.0        2.0  2040.0   138000.0      1954.0    2553.05  6037.0
# 170584        3.0        2.0  1834.0   263870.0      1959.0    3139.76  6059.0
# 2001226       2.0        2.0  1225.0   335603.0      1975.0    3461.38  6059.0
# ...           ...        ...     ...        ...         ...        ...     ...
# 562147        3.0        2.0  1161.0    65135.0      1956.0    1648.42  6037.0
# 1530656       3.0        2.0  2042.0   130866.0      1950.0    1531.56  6037.0
# 745152        4.0        2.0  1280.0    92456.0      1957.0    1904.80  6037.0
# 249374        2.0        1.0   748.0   226667.0      1920.0    3223.60  6037.0
# 1333156       3.0        2.0  1472.0   528455.0      1969.0    6182.88  6059.0
#
# [1192919 rows x 7 columns]
